# %%
import numpy as np
import pandas as pd

import category_encoders as ce
from tsforest.forecast import LightGBMForecaster

import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# ***
# ## data preparation

# %%
dataset = pd.read_parquet("../data/dataset.parquet")
dataset
# Out:
#                date     sku  sold_quantity  current_price currency  \
# 0        2021-02-01       0              0     172.789993      REA
# 1        2021-02-02       0              0     172.789993      REA
# 2        2021-02-03       0              0     179.990005      REA
# 3        2021-02-04       0              0     179.990005      REA
# 4        2021-02-05       0              0     179.990005      REA
# ...             ...     ...            ...            ...      ...
# 38994039 2021-03-27  660915              0      79.989998      MEX
# 38994040 2021-03-28  660915              0      79.989998      MEX
# 38994041 2021-03-29  660915              0      79.989998      MEX
# 38994042 2021-03-30  660915              0      99.989998      MEX
# 38994043 2021-03-31  660915              0      99.989998      MEX
#
#          listing_type shipping_logistic_type shipping_payment  minutes_active  \
# 0             classic          cross_docking    free_shipping        0.000000
# 1             classic          cross_docking    free_shipping        0.000000
# 2             classic          cross_docking    free_shipping      872.650024
# 3             classic          cross_docking    free_shipping     1440.000000
# 4             classic          cross_docking    free_shipping     1440.000000
# ...               ...                    ...              ...             ...
# 38994039      classic            fulfillment    paid_shipping        0.000000
# 38994040      classic            fulfillment    paid_shipping        0.000000
# 38994041      classic            fulfillment    paid_shipping        0.000000
# 38994042      classic            fulfillment    paid_shipping        0.000000
# 38994043      classic            fulfillment    paid_shipping        0.000000
#
#           available      item_domain_id  item_id site_id product_id  \
# 0                 1        MLB-SNEAKERS   492155     MLB       None
# 1                 1        MLB-SNEAKERS   492155     MLB       None
# 2                 1        MLB-SNEAKERS   492155     MLB       None
# 3                 1        MLB-SNEAKERS   492155     MLB       None
# 4                 1        MLB-SNEAKERS   492155     MLB       None
# ...             ...                 ...      ...     ...        ...
# 38994039          1  MLM-SURGICAL_MASKS   423179     MLM       None
# 38994040          1  MLM-SURGICAL_MASKS   423179     MLM       None
# 38994041          1  MLM-SURGICAL_MASKS   423179     MLM       None
# 38994042          1  MLM-SURGICAL_MASKS   423179     MLM       None
# 38994043          1  MLM-SURGICAL_MASKS   423179     MLM       None
#
#          product_family_id
# 0              MLB15832732
# 1              MLB15832732
# 2              MLB15832732
# 3              MLB15832732
# 4              MLB15832732
# ...                    ...
# 38994039              None
# 38994040              None
# 38994041              None
# 38994042              None
# 38994043              None
#
# [38994044 rows x 15 columns]

# %%
dataset.sold_quantity.describe()
# Out:
# count    3.899404e+07
# mean     9.562279e-01
# std      9.818856e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.000000e+00
# max      6.951000e+03
# Name: sold_quantity, dtype: float64

# %%
dataset["fold"] = dataset.date.dt.month - 2

categorical_features = {
    "sku":"default",
    "currency":"default",
    "listing_type":"default",
    "shipping_logistic_type":"default",
    "shipping_payment":"default",
    "item_domain_id":"default",
    "item_id":"default",
    "site_id":"default",
    "product_id":"default",
    "product_family_id":"default",
}

exclude_features = ["month","sold_quantity",]

#for col in categorical_features:
#    dataset[col] = pd.Categorical(dataset[col])

# %%
dataset.rename({"date":"ds", "sold_quantity":"y"}, axis=1, inplace=True)
dataset
# Out:
#                  ds     sku  y  current_price currency listing_type  \
# 0        2021-02-01       0  0     172.789993      REA      classic
# 1        2021-02-02       0  0     172.789993      REA      classic
# 2        2021-02-03       0  0     179.990005      REA      classic
# 3        2021-02-04       0  0     179.990005      REA      classic
# 4        2021-02-05       0  0     179.990005      REA      classic
# ...             ...     ... ..            ...      ...          ...
# 38994039 2021-03-27  660915  0      79.989998      MEX      classic
# 38994040 2021-03-28  660915  0      79.989998      MEX      classic
# 38994041 2021-03-29  660915  0      79.989998      MEX      classic
# 38994042 2021-03-30  660915  0      99.989998      MEX      classic
# 38994043 2021-03-31  660915  0      99.989998      MEX      classic
#
#          shipping_logistic_type shipping_payment  minutes_active  available  \
# 0                 cross_docking    free_shipping        0.000000          1
# 1                 cross_docking    free_shipping        0.000000          1
# 2                 cross_docking    free_shipping      872.650024          1
# 3                 cross_docking    free_shipping     1440.000000          1
# 4                 cross_docking    free_shipping     1440.000000          1
# ...                         ...              ...             ...        ...
# 38994039            fulfillment    paid_shipping        0.000000          1
# 38994040            fulfillment    paid_shipping        0.000000          1
# 38994041            fulfillment    paid_shipping        0.000000          1
# 38994042            fulfillment    paid_shipping        0.000000          1
# 38994043            fulfillment    paid_shipping        0.000000          1
#
#               item_domain_id  item_id site_id product_id product_family_id  \
# 0               MLB-SNEAKERS   492155     MLB       None       MLB15832732
# 1               MLB-SNEAKERS   492155     MLB       None       MLB15832732
# 2               MLB-SNEAKERS   492155     MLB       None       MLB15832732
# 3               MLB-SNEAKERS   492155     MLB       None       MLB15832732
# 4               MLB-SNEAKERS   492155     MLB       None       MLB15832732
# ...                      ...      ...     ...        ...               ...
# 38994039  MLM-SURGICAL_MASKS   423179     MLM       None              None
# 38994040  MLM-SURGICAL_MASKS   423179     MLM       None              None
# 38994041  MLM-SURGICAL_MASKS   423179     MLM       None              None
# 38994042  MLM-SURGICAL_MASKS   423179     MLM       None              None
# 38994043  MLM-SURGICAL_MASKS   423179     MLM       None              None
#
#           fold
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 38994039     1
# 38994040     1
# 38994041     1
# 38994042     1
# 38994043     1
#
# [38994044 rows x 16 columns]

# %% [markdown]
# ***
# ## model training

# %%
# model configuration
model_params = {
    'objective':'tweedie',
    'tweedie_variance_power': 1.1,
    'metric':'l1',
    'num_iterations':500,
    'max_bin': 127,
    'bin_construct_sample_cnt':20000000,
    'num_leaves': 2**10-1,
    'min_data_in_leaf': 2**10-1,
    'learning_rate': 0.05,
    'feature_fraction':0.8,
    'bagging_fraction':0.8,
    'bagging_freq':1,
    'lambda_l2':0.1,
    'boost_from_average': False,
}

time_features = [
    #"year",
    #"month",
    #"year_week",
    #"year_day",
    "week_day",
    "week_day_cos",
    "week_day_sin",
    "month_progress",
    #"year_day_cos",
    #"year_day_sin",
    #"year_week_cos",
    #"year_week_sin",
    #"month_cos",
    #"month_sin"
]

# %%
model_kwargs = {
    "model_params":model_params,
    "time_features":time_features,
    "exclude_features":exclude_features,
    "categorical_features":categorical_features,
    "ts_uid_columns":["sku",],
}

# %%
model = LightGBMForecaster(**model_kwargs)

# %%
for valid_fold in [1,0]:
    break

# %%
valid_idx = dataset.query("fold == @valid_fold").index

# %%
# %%time
model.prepare_features(dataset, valid_idx);

# %%
model.train_features

# %%
model.valid_features

# %%
help(model.fit)

# %%
# %%time
model.fit(fit_kwargs={"verbose_eval":50,})

# %% [markdown]
# ***
