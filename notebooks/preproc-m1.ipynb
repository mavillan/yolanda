# %%
import numpy as np
import pandas as pd
import jsonlines
from tqdm import tqdm
from joblib import Parallel, delayed

# %%
# mean over the period of train+test
MEX_TO_USD = 0.050
ARG_TO_USD = 0.011
REA_TO_USD = 0.18

# %% [markdown]
# ***
# ## preparing train data

# %%
train = pd.read_parquet("../data/train_data.parquet")
train["date"] = pd.to_datetime(train["date"])
train
# Out:
#              sku       date  sold_quantity  current_price currency  \
# 0         464801 2021-02-01              0         156.78      REA
# 1         464801 2021-02-02              0         156.78      REA
# 2         464801 2021-02-03              0         156.78      REA
# 3         464801 2021-02-04              0         156.78      REA
# 4         464801 2021-02-05              1         156.78      REA
# ...          ...        ...            ...            ...      ...
# 37660274  129187 2021-03-31              0       22057.00      ARG
# 37660275    6707 2021-03-31              0       26999.00      ARG
# 37660276  170355 2021-03-31              0        3400.00      ARG
# 37660277  246568 2021-03-31              0        6289.00      ARG
# 37660278   49718 2021-03-31              0        1990.00      ARG
#
#          listing_type shipping_logistic_type shipping_payment  minutes_active
# 0             classic            fulfillment    free_shipping     1440.000000
# 1             classic            fulfillment    free_shipping     1440.000000
# 2             classic            fulfillment    free_shipping     1440.000000
# 3             classic            fulfillment    free_shipping     1440.000000
# 4             classic            fulfillment    free_shipping     1440.000000
# ...               ...                    ...              ...             ...
# 37660274      classic               drop_off    free_shipping      267.710767
# 37660275      classic          cross_docking    free_shipping      266.083333
# 37660276      classic               drop_off    paid_shipping        0.252633
# 37660277      classic            fulfillment    free_shipping      135.416667
# 37660278      classic               drop_off    paid_shipping       88.033333
#
# [37660279 rows x 9 columns]

# %%
idx = train.query("currency == 'ARG'").index
train.loc[idx,"current_price"] = train.loc[idx,"current_price"]*ARG_TO_USD

idx = train.query("currency == 'REA'").index
train.loc[idx,"current_price"] = train.loc[idx,"current_price"]*REA_TO_USD

idx = train.query("currency == 'MEX'").index
train.loc[idx,"current_price"] = train.loc[idx,"current_price"]*MEX_TO_USD

# issue with particular gradient
train.loc[29044628,"current_price"] = train.loc[29044627,"current_price"]

train.drop("currency", axis=1, inplace=True)

# %%
all_records = list()
with jsonlines.open('../data/items_static_metadata_full.jl') as reader:
    for obj in tqdm(reader):
        all_records.append(obj)
        
metadata = pd.DataFrame(all_records)
metadata.drop(["item_title"], axis=1, inplace=True)

def fix_item_domain_id(x):
    try:
        return x.split("-")[1]
    except:
        return None

def fix_product_id(x):
    try:
        return x[3:]
    except:
        return None
    
def fix_product_family_id(x):
    try:
        return x[3:]
    except:
        return None

metadata["item_domain_id_glob"] = metadata.item_domain_id.apply(fix_item_domain_id)
metadata["product_id_glob"] = metadata.product_id.apply(fix_product_id)
metadata["product_family_id_glob"] = metadata.product_family_id.apply(fix_product_family_id)

metadata.to_csv("../data/metadata.csv", index=False)
metadata
# Out:
# 660916it [00:03, 195861.55it/s]
#                    item_domain_id  item_id site_id     sku product_id  \
# 0                    MLB-SNEAKERS   492155     MLB       0       None
# 1             MLB-SURFBOARD_RACKS   300279     MLB       1       None
# 2                   MLM-NECKLACES    69847     MLM       2       None
# 3                       MLM-RINGS   298603     MLM       3       None
# 4                     MLB-WEBCAMS   345949     MLB       4       None
# ...                           ...      ...     ...     ...        ...
# 660911        MLB-CELLPHONE_PARTS   320792     MLB  660911       None
# 660912     MLM-AUTOMOTIVE_EMBLEMS    90441     MLM  660912       None
# 660913  MLB-SOFA_AND_FUTON_COVERS   202580     MLB  660913       None
# 660914               MLB-SNEAKERS   490874     MLB  660914       None
# 660915         MLM-SURGICAL_MASKS   423179     MLM  660915       None
#
#        product_family_id    item_domain_id_glob product_id_glob  \
# 0            MLB15832732               SNEAKERS            None
# 1                   None        SURFBOARD_RACKS            None
# 2                   None              NECKLACES            None
# 3                   None                  RINGS            None
# 4                   None                WEBCAMS            None
# ...                  ...                    ...             ...
# 660911              None        CELLPHONE_PARTS            None
# 660912              None     AUTOMOTIVE_EMBLEMS            None
# 660913              None  SOFA_AND_FUTON_COVERS            None
# 660914              None               SNEAKERS            None
# 660915              None         SURGICAL_MASKS            None
#
#        product_family_id_glob
# 0                    15832732
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# ...                       ...
# 660911                   None
# 660912                   None
# 660913                   None
# 660914                   None
# 660915                   None
#
# [660916 rows x 9 columns]

# %%
metadata.nunique(axis=0)
# Out:
# item_domain_id              8408
# item_id                   517896
# site_id                        3
# sku                       660916
# product_id                 15863
# product_family_id          29600
# item_domain_id_glob         3595
# product_id_glob            14631
# product_family_id_glob     27272
# dtype: int64

# %%
train = pd.merge(train, metadata, how="inner", on="sku")
train
# Out:
#              sku       date  sold_quantity  current_price listing_type  \
# 0         464801 2021-02-01              0        28.2204      classic
# 1         464801 2021-02-02              0        28.2204      classic
# 2         464801 2021-02-03              0        28.2204      classic
# 3         464801 2021-02-04              0        28.2204      classic
# 4         464801 2021-02-05              1        28.2204      classic
# ...          ...        ...            ...            ...          ...
# 37660274  129187 2021-03-31              0       242.6270      classic
# 37660275    6707 2021-03-31              0       296.9890      classic
# 37660276  170355 2021-03-31              0        37.4000      classic
# 37660277  246568 2021-03-31              0        69.1790      classic
# 37660278   49718 2021-03-31              0        21.8900      classic
#
#          shipping_logistic_type shipping_payment  minutes_active  \
# 0                   fulfillment    free_shipping     1440.000000
# 1                   fulfillment    free_shipping     1440.000000
# 2                   fulfillment    free_shipping     1440.000000
# 3                   fulfillment    free_shipping     1440.000000
# 4                   fulfillment    free_shipping     1440.000000
# ...                         ...              ...             ...
# 37660274               drop_off    free_shipping      267.710767
# 37660275          cross_docking    free_shipping      266.083333
# 37660276               drop_off    paid_shipping        0.252633
# 37660277            fulfillment    free_shipping      135.416667
# 37660278               drop_off    paid_shipping       88.033333
#
#                     item_domain_id  item_id site_id   product_id  \
# 0                   MLB-NEBULIZERS   344151     MLB   MLB9838512
# 1                   MLB-NEBULIZERS   344151     MLB   MLB9838512
# 2                   MLB-NEBULIZERS   344151     MLB   MLB9838512
# 3                   MLB-NEBULIZERS   344151     MLB   MLB9838512
# 4                   MLB-NEBULIZERS   344151     MLB   MLB9838512
# ...                            ...      ...     ...          ...
# 37660274   MLA-RADIO_BASE_STATIONS   408559     MLA         None
# 37660275              MLA-PRINTERS   193784     MLA  MLA15159034
# 37660276          MLA-WRISTWATCHES   110276     MLA         None
# 37660277  MLA-HARD_DRIVES_AND_SSDS   456892     MLA  MLA15697725
# 37660278          MLA-THERMAL_PADS   245547     MLA         None
#
#          product_family_id   item_domain_id_glob product_id_glob  \
# 0               MLB9838510            NEBULIZERS         9838512
# 1               MLB9838510            NEBULIZERS         9838512
# 2               MLB9838510            NEBULIZERS         9838512
# 3               MLB9838510            NEBULIZERS         9838512
# 4               MLB9838510            NEBULIZERS         9838512
# ...                    ...                   ...             ...
# 37660274              None   RADIO_BASE_STATIONS            None
# 37660275       MLA15159032              PRINTERS        15159034
# 37660276              None          WRISTWATCHES            None
# 37660277       MLA15697724  HARD_DRIVES_AND_SSDS        15697725
# 37660278              None          THERMAL_PADS            None
#
#          product_family_id_glob
# 0                       9838510
# 1                       9838510
# 2                       9838510
# 3                       9838510
# 4                       9838510
# ...                         ...
# 37660274                   None
# 37660275               15159032
# 37660276                   None
# 37660277               15697724
# 37660278                   None
#
# [37660279 rows x 16 columns]

# %% [markdown]
# ***
# ## preparing test data

# %%
cols = [
    "sku","current_price", "listing_type", 
    "shipping_logistic_type", "shipping_payment", "minutes_active", 
    "item_domain_id", "item_id", "site_id", "product_id",
    "product_family_id", "item_domain_id_glob", "product_family_id_glob",
    "product_id_glob",
]

def get_train_feats(df, look_back=28):
    record = df.tail(look_back)[cols].mode()
    return record.to_dict(orient="records")[0]

# %%
with Parallel(n_jobs=6) as parallel:
    delayed_func = delayed(get_train_feats)
    all_rows = parallel(delayed_func(df) for _,df in tqdm(train.groupby("sku")))
train_feats = pd.DataFrame(all_rows)

train_feats["sku"] = train_feats["sku"].astype(int)
train_feats = train_feats.replace({np.nan: None})

train_feats
# Out:
# 100%|██████████| 660916/660916 [27:41<00:00, 397.82it/s]
#            sku  current_price listing_type shipping_logistic_type  \
# 0            0        32.3982      classic            fulfillment
# 1            1        24.4620      premium            fulfillment
# 2            2        10.9500      premium               drop_off
# 3            3        19.9500      premium            fulfillment
# 4            4        21.2400      premium            fulfillment
# ...        ...            ...          ...                    ...
# 660911  660911         2.3220      classic            fulfillment
# 660912  660912         4.9500      classic            fulfillment
# 660913  660913        23.0544      premium            fulfillment
# 660914  660914         9.5382      premium            fulfillment
# 660915  660915         3.8995      classic            fulfillment
#
#        shipping_payment  minutes_active             item_domain_id   item_id  \
# 0         free_shipping          1440.0               MLB-SNEAKERS  492155.0
# 1         free_shipping          1440.0        MLB-SURFBOARD_RACKS  300279.0
# 2         paid_shipping          1440.0              MLM-NECKLACES   69847.0
# 3         free_shipping             0.0                  MLM-RINGS  298603.0
# 4         free_shipping             0.0                MLB-WEBCAMS  345949.0
# ...                 ...             ...                        ...       ...
# 660911    paid_shipping          1440.0        MLB-CELLPHONE_PARTS  320792.0
# 660912    paid_shipping          1440.0     MLM-AUTOMOTIVE_EMBLEMS   90441.0
# 660913    free_shipping          1440.0  MLB-SOFA_AND_FUTON_COVERS  202580.0
# 660914    paid_shipping          1440.0               MLB-SNEAKERS  490874.0
# 660915    paid_shipping             0.0         MLM-SURGICAL_MASKS  423179.0
#
#        site_id product_id product_family_id    item_domain_id_glob  \
# 0          MLB       None       MLB15832732               SNEAKERS
# 1          MLB       None              None        SURFBOARD_RACKS
# 2          MLM       None              None              NECKLACES
# 3          MLM       None              None                  RINGS
# 4          MLB       None              None                WEBCAMS
# ...        ...        ...               ...                    ...
# 660911     MLB       None              None        CELLPHONE_PARTS
# 660912     MLM       None              None     AUTOMOTIVE_EMBLEMS
# 660913     MLB       None              None  SOFA_AND_FUTON_COVERS
# 660914     MLB       None              None               SNEAKERS
# 660915     MLM       None              None         SURGICAL_MASKS
#
#        product_family_id_glob product_id_glob
# 0                    15832732            None
# 1                        None            None
# 2                        None            None
# 3                        None            None
# 4                        None            None
# ...                       ...             ...
# 660911                   None            None
# 660912                   None            None
# 660913                   None            None
# 660914                   None            None
# 660915                   None            None
#
# [660916 rows x 14 columns]

# %%
train_feats.isna().sum(axis=0) / len(train_feats)
# Out:
# sku                       0.000000
# current_price             0.000000
# listing_type              0.000000
# shipping_logistic_type    0.000000
# shipping_payment          0.000000
# minutes_active            0.000000
# item_domain_id            0.000005
# item_id                   0.000000
# site_id                   0.000000
# product_id                0.955111
# product_family_id         0.874138
# item_domain_id_glob       0.000005
# product_family_id_glob    0.874138
# product_id_glob           0.955111
# dtype: float64

# %%
test = pd.read_csv("../data/test_data.csv")
test = pd.merge(test, train_feats, how="left", on="sku")
test
# Out:
#            sku  target_stock  current_price listing_type  \
# 0       464801             3        30.5982      classic
# 1       645793             4        29.6982      classic
# 2        99516             8         4.1220      premium
# 3       538100             8         5.0580      premium
# 4       557191            10         8.9820      premium
# ...        ...           ...            ...          ...
# 551467  129187             8       242.6270      classic
# 551468    6707            30       296.9890      classic
# 551469  170355             3        37.4000      classic
# 551470  246568             2        69.1790      classic
# 551471   49718            20        21.8900      classic
#
#        shipping_logistic_type shipping_payment  minutes_active  \
# 0                 fulfillment    free_shipping     1440.000000
# 1                 fulfillment    free_shipping     1440.000000
# 2                 fulfillment    paid_shipping     1440.000000
# 3                 fulfillment    paid_shipping     1440.000000
# 4                 fulfillment    paid_shipping        0.000000
# ...                       ...              ...             ...
# 551467               drop_off    free_shipping      267.710767
# 551468          cross_docking    free_shipping      266.083333
# 551469               drop_off    paid_shipping        0.252633
# 551470            fulfillment    free_shipping      135.416667
# 551471               drop_off    paid_shipping       88.033333
#
#                      item_domain_id   item_id site_id   product_id  \
# 0                    MLB-NEBULIZERS  344151.0     MLB   MLB9838512
# 1                    MLB-NEBULIZERS  438135.0     MLB         None
# 2                MLB-ADHESIVE_TAPES  221252.0     MLB         None
# 3       MLB-SCHOOL_AND_OFFICE_GLUES   62099.0     MLB         None
# 4             MLB-DECORATIVE_VINYLS  168198.0     MLB         None
# ...                             ...       ...     ...          ...
# 551467      MLA-RADIO_BASE_STATIONS  408559.0     MLA         None
# 551468                 MLA-PRINTERS  193784.0     MLA  MLA15159034
# 551469             MLA-WRISTWATCHES  110276.0     MLA         None
# 551470     MLA-HARD_DRIVES_AND_SSDS  456892.0     MLA  MLA15697725
# 551471             MLA-THERMAL_PADS  245547.0     MLA         None
#
#        product_family_id      item_domain_id_glob product_family_id_glob  \
# 0             MLB9838510               NEBULIZERS                9838510
# 1             MLB9838510               NEBULIZERS                9838510
# 2                   None           ADHESIVE_TAPES                   None
# 3                   None  SCHOOL_AND_OFFICE_GLUES                   None
# 4                   None        DECORATIVE_VINYLS                   None
# ...                  ...                      ...                    ...
# 551467              None      RADIO_BASE_STATIONS                   None
# 551468       MLA15159032                 PRINTERS               15159032
# 551469              None             WRISTWATCHES                   None
# 551470       MLA15697724     HARD_DRIVES_AND_SSDS               15697724
# 551471              None             THERMAL_PADS                   None
#
#        product_id_glob
# 0              9838512
# 1                 None
# 2                 None
# 3                 None
# 4                 None
# ...                ...
# 551467            None
# 551468        15159034
# 551469            None
# 551470        15697725
# 551471            None
#
# [551472 rows x 15 columns]

# %%
all_dfs = list()

for date in pd.date_range("2021-04-01", "2021-04-30"):
    _test = test.copy(deep=True)
    _test["date"] = date
    all_dfs.append(_test)
    
test = pd.concat(all_dfs, ignore_index=True)
test
# Out:
#              sku  target_stock  current_price listing_type  \
# 0         464801             3        30.5982      classic
# 1         645793             4        29.6982      classic
# 2          99516             8         4.1220      premium
# 3         538100             8         5.0580      premium
# 4         557191            10         8.9820      premium
# ...          ...           ...            ...          ...
# 16544155  129187             8       242.6270      classic
# 16544156    6707            30       296.9890      classic
# 16544157  170355             3        37.4000      classic
# 16544158  246568             2        69.1790      classic
# 16544159   49718            20        21.8900      classic
#
#          shipping_logistic_type shipping_payment  minutes_active  \
# 0                   fulfillment    free_shipping     1440.000000
# 1                   fulfillment    free_shipping     1440.000000
# 2                   fulfillment    paid_shipping     1440.000000
# 3                   fulfillment    paid_shipping     1440.000000
# 4                   fulfillment    paid_shipping        0.000000
# ...                         ...              ...             ...
# 16544155               drop_off    free_shipping      267.710767
# 16544156          cross_docking    free_shipping      266.083333
# 16544157               drop_off    paid_shipping        0.252633
# 16544158            fulfillment    free_shipping      135.416667
# 16544159               drop_off    paid_shipping       88.033333
#
#                        item_domain_id   item_id site_id   product_id  \
# 0                      MLB-NEBULIZERS  344151.0     MLB   MLB9838512
# 1                      MLB-NEBULIZERS  438135.0     MLB         None
# 2                  MLB-ADHESIVE_TAPES  221252.0     MLB         None
# 3         MLB-SCHOOL_AND_OFFICE_GLUES   62099.0     MLB         None
# 4               MLB-DECORATIVE_VINYLS  168198.0     MLB         None
# ...                               ...       ...     ...          ...
# 16544155      MLA-RADIO_BASE_STATIONS  408559.0     MLA         None
# 16544156                 MLA-PRINTERS  193784.0     MLA  MLA15159034
# 16544157             MLA-WRISTWATCHES  110276.0     MLA         None
# 16544158     MLA-HARD_DRIVES_AND_SSDS  456892.0     MLA  MLA15697725
# 16544159             MLA-THERMAL_PADS  245547.0     MLA         None
#
#          product_family_id      item_domain_id_glob product_family_id_glob  \
# 0               MLB9838510               NEBULIZERS                9838510
# 1               MLB9838510               NEBULIZERS                9838510
# 2                     None           ADHESIVE_TAPES                   None
# 3                     None  SCHOOL_AND_OFFICE_GLUES                   None
# 4                     None        DECORATIVE_VINYLS                   None
# ...                    ...                      ...                    ...
# 16544155              None      RADIO_BASE_STATIONS                   None
# 16544156       MLA15159032                 PRINTERS               15159032
# 16544157              None             WRISTWATCHES                   None
# 16544158       MLA15697724     HARD_DRIVES_AND_SSDS               15697724
# 16544159              None             THERMAL_PADS                   None
#
#          product_id_glob       date
# 0                9838512 2021-04-01
# 1                   None 2021-04-01
# 2                   None 2021-04-01
# 3                   None 2021-04-01
# 4                   None 2021-04-01
# ...                  ...        ...
# 16544155            None 2021-04-30
# 16544156        15159034 2021-04-30
# 16544157            None 2021-04-30
# 16544158        15697725 2021-04-30
# 16544159            None 2021-04-30
#
# [16544160 rows x 16 columns]

# %% [markdown]
# ***
# ## saving the results

# %%
import sys
sys.path.append("../utils")
from memory import reduce_mem_usage

# %%
train = reduce_mem_usage(train, verbose=True)
train.to_parquet("../data/train-m1.parquet", index=False)
# Out:
# Mem. usage decreased to 4094.38 Mb (16.2% reduction)

# %%
test = reduce_mem_usage(test, verbose=True)
test.to_parquet("../data/test-m1.parquet", index=False)
# Out:
# Mem. usage decreased to 1672.44 Mb (17.2% reduction)

# %% [markdown]
# ***
