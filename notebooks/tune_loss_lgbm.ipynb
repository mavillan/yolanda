# %% [markdown]
# <a href="https://colab.research.google.com/github/mavillan/yolanda/blob/main/notebooks/tune_loss_lgbm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***
# ## notebook config

# %%
from google.colab import drive
from google.colab import files
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install --upgrade kaggle > /dev/null 2>&1
# !mkdir -p ~/.kaggle/ && cp /content/drive/MyDrive/kaggle/kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
# !free -h
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:            35G        1.1G         27G        1.1M        6.7G         33G
# Swap:            0B          0B          0B

# %%
# !pip install --upgrade category_encoders > /dev/null 2>&1
# !pip install --upgrade tsforest > /dev/null 2>&1
#!pip install --upgrade lightgbm > /dev/null 2>&1

# %%
# %%bash
# git clone --recursive https://github.com/microsoft/LightGBM ; cd LightGBM
# mkdir build
# #export CMAKE_CXX_FLAGS='-O3 -mtune=native'
# cmake -DUSE_GPU=1
# make -j$(nproc)
# cd ./python-package/
# python setup.py install --precompile
#
# # THIS IS FOR GPU INSTALLATION

# %%
# %%bash
# git clone --recursive https://github.com/microsoft/LightGBM ; cd LightGBM
# mkdir build ; cd build
# export CMAKE_CXX_FLAGS='-O3 -mtune=native'
# cmake ..
# make -j$(nproc)
# cd ../python-package/
# python setup.py install --precompile
#
# # THIS IS FOR CPU (OPTIMIZED) INSTALLATION

# %% [markdown]
# ***

# %%
from copy import deepcopy
import gc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time

import category_encoders as ce
import lightgbm as lgb
from tsforest.forecast import LightGBMForecaster

pd.set_option('display.max_columns', None)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
def reduce_mem_usage(df, verbose=False):
    """
    Utility function to reduce the memory usage of pandas dataframes
    
    Parameters
    ----------
    df: pandas.Dataframe
    verbose: Boolean
    """
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: 
        print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
class RMSSE():
    def __init__(self, valid_dataframe, scales_dataframe):
        self.valid_dataframe = valid_dataframe
        self.scales_dataframe = scales_dataframe

    def _evaluate(self, predictions):
        valid_dataframe = self.valid_dataframe.copy()
        valid_dataframe["ypred"] = predictions
        valid_dataframe["sq_error"] = valid_dataframe.eval("(y-ypred)**2")
        mse = valid_dataframe.groupby("sku")["sq_error"].mean().reset_index(name="mse")
        mrg = pd.merge(mse, self.scales_dataframe, how="inner", on="sku")
        return mrg.eval("sqrt(mse)/scale").mean()

    def evaluate(self, ypred, dtrain):
        metric = self._evaluate(ypred)
        return "rmsse", metric, False

# %% [markdown]
# ***
# ## data preparation

# %%
# !kaggle datasets download -d mavillan/meli-2021 --force --unzip
# !ls -halt
# Out:
# Downloading meli-2021.zip to /content
#  96% 218M/227M [00:02<00:00, 125MB/s]
# 100% 227M/227M [00:02<00:00, 98.5MB/s]
# total 316M
# drwxr-xr-x  1 root root 4.0K Aug 10 15:50 .
# -rw-r--r--  1 root root 169K Aug 10 15:50 unpredictable.csv
# -rw-r--r--  1 root root  78M Aug 10 15:50 train.parquet
# -rw-r--r--  1 root root 223M Aug 10 15:50 test.parquet
# -rw-r--r--  1 root root  16M Aug 10 15:49 scales.csv
# drwx------  5 root root 4.0K Aug 10 15:49 drive
# drwxr-xr-x 21 root root 4.0K Aug 10 14:43 LightGBM
# drwxr-xr-x  1 root root 4.0K Aug 10 14:40 ..
# drwxr-xr-x  1 root root 4.0K Jul 16 13:20 sample_data
# drwxr-xr-x  4 root root 4.0K Jul 16 13:19 .config

# %%
dataset = pd.read_parquet("./train.parquet")
dataset.rename({"date":"ds", "sold_quantity":"y"}, axis=1, inplace=True)
dataset
# Out:
#                  ds     sku  y  current_price currency listing_type  \
# 0        2021-02-01       0  0     172.789993      REA      classic
# 1        2021-02-02       0  0     172.789993      REA      classic
# 2        2021-02-03       0  0     179.990005      REA      classic
# 3        2021-02-04       0  0     179.990005      REA      classic
# 4        2021-02-05       0  0     179.990005      REA      classic
# ...             ...     ... ..            ...      ...          ...
# 37660274 2021-03-27  660915  0      79.989998      MEX      classic
# 37660275 2021-03-28  660915  0      79.989998      MEX      classic
# 37660276 2021-03-29  660915  0      79.989998      MEX      classic
# 37660277 2021-03-30  660915  0      99.989998      MEX      classic
# 37660278 2021-03-31  660915  0      99.989998      MEX      classic
#
#          shipping_logistic_type shipping_payment  minutes_active  available  \
# 0                 cross_docking    free_shipping        0.000000          1
# 1                 cross_docking    free_shipping        0.000000          1
# 2                 cross_docking    free_shipping      872.650024          1
# 3                 cross_docking    free_shipping     1440.000000          1
# 4                 cross_docking    free_shipping     1440.000000          1
# ...                         ...              ...             ...        ...
# 37660274            fulfillment    paid_shipping        0.000000          1
# 37660275            fulfillment    paid_shipping        0.000000          1
# 37660276            fulfillment    paid_shipping        0.000000          1
# 37660277            fulfillment    paid_shipping        0.000000          1
# 37660278            fulfillment    paid_shipping        0.000000          1
#
#               item_domain_id  item_id site_id product_id product_family_id
# 0               MLB-SNEAKERS   492155     MLB       None       MLB15832732
# 1               MLB-SNEAKERS   492155     MLB       None       MLB15832732
# 2               MLB-SNEAKERS   492155     MLB       None       MLB15832732
# 3               MLB-SNEAKERS   492155     MLB       None       MLB15832732
# 4               MLB-SNEAKERS   492155     MLB       None       MLB15832732
# ...                      ...      ...     ...        ...               ...
# 37660274  MLM-SURGICAL_MASKS   423179     MLM       None              None
# 37660275  MLM-SURGICAL_MASKS   423179     MLM       None              None
# 37660276  MLM-SURGICAL_MASKS   423179     MLM       None              None
# 37660277  MLM-SURGICAL_MASKS   423179     MLM       None              None
# 37660278  MLM-SURGICAL_MASKS   423179     MLM       None              None
#
# [37660279 rows x 15 columns]

# %%
unpredictable = pd.read_csv("unpredictable.csv")
scales = pd.read_csv("scales.csv")

dataset = dataset.query("sku not in @unpredictable.sku").reset_index(drop=True)
dataset
# Out:
#                  ds     sku  y  current_price currency listing_type  \
# 0        2021-02-01       0  0     172.789993      REA      classic
# 1        2021-02-02       0  0     172.789993      REA      classic
# 2        2021-02-03       0  0     179.990005      REA      classic
# 3        2021-02-04       0  0     179.990005      REA      classic
# 4        2021-02-05       0  0     179.990005      REA      classic
# ...             ...     ... ..            ...      ...          ...
# 36594391 2021-03-27  660915  0      79.989998      MEX      classic
# 36594392 2021-03-28  660915  0      79.989998      MEX      classic
# 36594393 2021-03-29  660915  0      79.989998      MEX      classic
# 36594394 2021-03-30  660915  0      99.989998      MEX      classic
# 36594395 2021-03-31  660915  0      99.989998      MEX      classic
#
#          shipping_logistic_type shipping_payment  minutes_active  available  \
# 0                 cross_docking    free_shipping        0.000000          1
# 1                 cross_docking    free_shipping        0.000000          1
# 2                 cross_docking    free_shipping      872.650024          1
# 3                 cross_docking    free_shipping     1440.000000          1
# 4                 cross_docking    free_shipping     1440.000000          1
# ...                         ...              ...             ...        ...
# 36594391            fulfillment    paid_shipping        0.000000          1
# 36594392            fulfillment    paid_shipping        0.000000          1
# 36594393            fulfillment    paid_shipping        0.000000          1
# 36594394            fulfillment    paid_shipping        0.000000          1
# 36594395            fulfillment    paid_shipping        0.000000          1
#
#               item_domain_id  item_id site_id product_id product_family_id
# 0               MLB-SNEAKERS   492155     MLB       None       MLB15832732
# 1               MLB-SNEAKERS   492155     MLB       None       MLB15832732
# 2               MLB-SNEAKERS   492155     MLB       None       MLB15832732
# 3               MLB-SNEAKERS   492155     MLB       None       MLB15832732
# 4               MLB-SNEAKERS   492155     MLB       None       MLB15832732
# ...                      ...      ...     ...        ...               ...
# 36594391  MLM-SURGICAL_MASKS   423179     MLM       None              None
# 36594392  MLM-SURGICAL_MASKS   423179     MLM       None              None
# 36594393  MLM-SURGICAL_MASKS   423179     MLM       None              None
# 36594394  MLM-SURGICAL_MASKS   423179     MLM       None              None
# 36594395  MLM-SURGICAL_MASKS   423179     MLM       None              None
#
# [36594396 rows x 15 columns]

# %%
categorical_features = {
    "sku": ("y", ce.CatBoostEncoder, None),
    "currency": "default",
    "listing_type": "default",
    "shipping_logistic_type": "default",
    "shipping_payment": "default",
    "item_domain_id": ("y", ce.CatBoostEncoder, None),
    "item_id": ("y", ce.CatBoostEncoder, None),
    "site_id":"default",
    "product_id": ("y", ce.CatBoostEncoder, None),
    "product_family_id": ("y", ce.CatBoostEncoder, None),
}

exclude_features = ["fold","sold_quantity",]

# %%
dataset.loc[:,categorical_features.keys()].nunique()
# Out:
# sku                       635633
# currency                       4
# listing_type                   2
# shipping_logistic_type         3
# shipping_payment               2
# item_domain_id              8372
# item_id                   497537
# site_id                        3
# product_id                 15237
# product_family_id          28817
# dtype: int64

# %%
dataset.groupby("site_id")["sku"].nunique()
# Out:
# site_id
# MLA     55514
# MLB    323896
# MLM    256223
# Name: sku, dtype: int64

# %% [markdown]
# ***
# ## model config

# %%
# model configuration
model_params = {
    'metric':'None',
    'num_iterations':500,
    'max_bin': 63,
    'bin_construct_sample_cnt':20000000,
    'num_leaves': 2**8-1,
    'min_data_in_leaf': 2**8-1,
    'learning_rate': 0.05,
    'feature_fraction':0.8,
    'bagging_fraction':0.8,
    'bagging_freq':1,
    'lambda_l2':0.1,
    'boost_from_average': False,
    'force_row_wise': True,
    #'device_type': 'gpu',
    #'num_gpu' : 1,
}
time_features = [
    "week_day",
    "week_day_cos",
    "week_day_sin",
    "month_progress",
]
model_kwargs = {
    "model_params":model_params,
    "time_features":time_features,
    "exclude_features":exclude_features,
    "categorical_features":categorical_features,
    "ts_uid_columns":["sku",],
}

# %% [markdown]
# ***
# ## Model assessment: huber loss

# %%
base_models = list()

for site in ["MLA","MLB","MLM"]:
    
    print("-"*75)
    print(f"Preparing model for site: {site}")
    model = LightGBMForecaster(**model_kwargs)

    tic = time.time()
    skus_both = set(dataset.query("ds <= '2021-03-01'").sku) & set(dataset.query("ds > '2021-03-01'").sku)
    train_data = dataset.query("site_id == @site & sku in @skus_both").reset_index(drop=True)
    valid_idx = train_data.query("ds > '2021-03-01'").index
    model.prepare_features(train_data, valid_idx)
    model.train_features = reduce_mem_usage(model.train_features, verbose=True)
    model.valid_features = reduce_mem_usage(model.valid_features, verbose=True)
    base_models.append(model)
    gc.collect()
    tac = time.time()
    print(f"Elapsed time for processing features: {(tac-tic)/60} min.")
# Out:
# ---------------------------------------------------------------------------
# Preparing model for site: MLA
# Mem. usage decreased to 142.60 Mb (42.9% reduction)
# Mem. usage decreased to 109.13 Mb (51.0% reduction)
# Elapsed time for processing features: 0.5590566992759705 min.
# ---------------------------------------------------------------------------
# Preparing model for site: MLB
# Mem. usage decreased to 931.03 Mb (40.6% reduction)
# Mem. usage decreased to 645.92 Mb (51.0% reduction)
# Elapsed time for processing features: 2.6765679836273195 min.
# ---------------------------------------------------------------------------
# Preparing model for site: MLM
# Mem. usage decreased to 801.00 Mb (38.5% reduction)
# Mem. usage decreased to 509.43 Mb (51.0% reduction)
# Elapsed time for processing features: 2.018024524052938 min.

# %%
results = list()

for alpha in np.arange(0.2, 2.01, 0.2):

    _model_params = dict(model_params)
    _model_params["objective"] = "huber"
    _model_params["alpha"] = alpha

    models_by_site = list()

    for idx,site in enumerate(["MLA","MLB","MLM"]):
        
        print("-"*75)
        print(f"Training model for site: {site}")
        model = deepcopy(base_models[idx])
        model.set_params(_model_params)

        train_data = dataset.query("site_id == @site & sku in @skus_both").reset_index(drop=True)
        valid_idx = train_data.query("ds > '2021-03-01'").index

        tic = time.time()
        evaluator = RMSSE(train_data.loc[valid_idx, ["sku","y"]], scales)
        model.fit(fit_kwargs={"verbose_eval":50, "feval":evaluator.evaluate})
        models_by_site.append(model)
        tac = time.time()
        print(f"Elapsed time for training the model: {(tac-tic)/60} min.")

    errors = list()
    sites = ["MLA","MLB","MLM"]
    for site,model in zip(sites,models_by_site):
        error = model.model.model.best_score["valid_0"]["rmsse"]
        errors.append(error)
        print(site, f"error: {error}")

    results.append({
        "alpha":alpha, 
        "rmsse_MLA":errors[0], 
        "rmsse_MLB":errors[1],
        "rmsse_MLM":errors[2],
        "rmsse_AVG":np.mean(errors),
    })

    del models_by_site
    gc.collect()
# Out:
# ---------------------------------------------------------------------------
# Training model for site: MLA
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 1515336, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.837888
# [100]	valid_0's rmsse: 0.826624
# [150]	valid_0's rmsse: 0.818954
# [200]	valid_0's rmsse: 0.813477
# [250]	valid_0's rmsse: 0.809757
# [300]	valid_0's rmsse: 0.807328
# [350]	valid_0's rmsse: 0.805413
# [400]	valid_0's rmsse: 0.803903
# [450]	valid_0's rmsse: 0.802727
# [500]	valid_0's rmsse: 0.801752
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's rmsse: 0.801752
# Elapsed time for training the model: 2.0044432282447815 min.
# ---------------------------------------------------------------------------
# Training model for site: MLB
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 9024166, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.906023
# [100]	valid_0's rmsse: 0.892571
# [150]	valid_0's rmsse: 0.883114
# [200]	valid_0's rmsse: 0.87618
# [250]	valid_0's rmsse: 0.871407
# [300]	valid_0's rmsse: 0.868298
# [350]	valid_0's rmsse: 0.865779
# [400]	valid_0's rmsse: 0.863859
# [450]	valid_0's rmsse: 0.862316
# [500]	valid_0's rmsse: 0.861092
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's rmsse: 0.861092
# Elapsed time for training the model: 5.777613858381907 min.
# ---------------------------------------------------------------------------
# Training model for site: MLM
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 7103708, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.825757
# [100]	valid_0's rmsse: 0.812074
# [150]	valid_0's rmsse: 0.802884
# [200]	valid_0's rmsse: 0.796445
# [250]	valid_0's rmsse: 0.792207
# [300]	valid_0's rmsse: 0.789406
# [350]	valid_0's rmsse: 0.787266
# [400]	valid_0's rmsse: 0.785634
# [450]	valid_0's rmsse: 0.784405
# [500]	valid_0's rmsse: 0.783388
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's rmsse: 0.783388
# Elapsed time for training the model: 4.941627260049184 min.
# MLA error: 0.8017521173492006
# MLB error: 0.861091887182725
# MLM error: 0.7833882897338458
# ---------------------------------------------------------------------------
# Training model for site: MLA
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 1515336, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.815714
# [100]	valid_0's rmsse: 0.801183
# [150]	valid_0's rmsse: 0.794974
# [200]	valid_0's rmsse: 0.791699
# [250]	valid_0's rmsse: 0.789579
# [300]	valid_0's rmsse: 0.788375
# [350]	valid_0's rmsse: 0.787481
# [400]	valid_0's rmsse: 0.786778
# [450]	valid_0's rmsse: 0.786304
# [500]	valid_0's rmsse: 0.785907
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's rmsse: 0.785907
# Elapsed time for training the model: 1.8885555942853292 min.
# ---------------------------------------------------------------------------
# Training model for site: MLB
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 9024166, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.880091
# [100]	valid_0's rmsse: 0.862104
# [150]	valid_0's rmsse: 0.854087
# [200]	valid_0's rmsse: 0.849791
# [250]	valid_0's rmsse: 0.84731
# [300]	valid_0's rmsse: 0.845939
# [350]	valid_0's rmsse: 0.844816
# [400]	valid_0's rmsse: 0.843992
# [450]	valid_0's rmsse: 0.843343
# [500]	valid_0's rmsse: 0.842854
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's rmsse: 0.842851
# Elapsed time for training the model: 5.505093955993653 min.
# ---------------------------------------------------------------------------
# Training model for site: MLM
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 7103708, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.800849
# [100]	valid_0's rmsse: 0.783482
# [150]	valid_0's rmsse: 0.776555
# [200]	valid_0's rmsse: 0.772983
# [250]	valid_0's rmsse: 0.770976
# [300]	valid_0's rmsse: 0.769913
# [350]	valid_0's rmsse: 0.769127
# [400]	valid_0's rmsse: 0.768571
# [450]	valid_0's rmsse: 0.768183
# [500]	valid_0's rmsse: 0.767874
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's rmsse: 0.76786
# Elapsed time for training the model: 4.619503533840179 min.
# MLA error: 0.7859069035516271
# MLB error: 0.842850917332294
# MLM error: 0.7678604485010555
# ---------------------------------------------------------------------------
# Training model for site: MLA
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 1515336, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.800536
# [100]	valid_0's rmsse: 0.788499
# [150]	valid_0's rmsse: 0.784295
# [200]	valid_0's rmsse: 0.781999
# [250]	valid_0's rmsse: 0.780648
# [300]	valid_0's rmsse: 0.779912
# [350]	valid_0's rmsse: 0.779432
# [400]	valid_0's rmsse: 0.779004
# [450]	valid_0's rmsse: 0.77873
# [500]	valid_0's rmsse: 0.778498
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's rmsse: 0.778498
# Elapsed time for training the model: 2.0767786502838135 min.
# ---------------------------------------------------------------------------
# Training model for site: MLB
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 9024166, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.861934
# [100]	valid_0's rmsse: 0.846583
# [150]	valid_0's rmsse: 0.840984
# [200]	valid_0's rmsse: 0.838192
# [250]	valid_0's rmsse: 0.836487
# [300]	valid_0's rmsse: 0.835703
# [350]	valid_0's rmsse: 0.835026
# [400]	valid_0's rmsse: 0.834581
# [450]	valid_0's rmsse: 0.834222
# [500]	valid_0's rmsse: 0.833971
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's rmsse: 0.833971
# Elapsed time for training the model: 5.880433710416158 min.
# ---------------------------------------------------------------------------
# Training model for site: MLM
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 7103708, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.78438
# [100]	valid_0's rmsse: 0.770245
# [150]	valid_0's rmsse: 0.765724
# [200]	valid_0's rmsse: 0.763656
# [250]	valid_0's rmsse: 0.762505
# [300]	valid_0's rmsse: 0.761982
# [350]	valid_0's rmsse: 0.761594
# [400]	valid_0's rmsse: 0.761334
# [450]	valid_0's rmsse: 0.761123
# [500]	valid_0's rmsse: 0.760989
# Did not meet early stopping. Best iteration is:
# [493]	valid_0's rmsse: 0.760988
# Elapsed time for training the model: 4.525034137566885 min.
# MLA error: 0.7784982015759357
# MLB error: 0.833971266318235
# MLM error: 0.7609882943012625
# ---------------------------------------------------------------------------
# Training model for site: MLA
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 1515336, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.792054
# [100]	valid_0's rmsse: 0.781968
# [150]	valid_0's rmsse: 0.778775
# [200]	valid_0's rmsse: 0.777182
# [250]	valid_0's rmsse: 0.776164
# [300]	valid_0's rmsse: 0.775695
# [350]	valid_0's rmsse: 0.775335
# [400]	valid_0's rmsse: 0.775094
# [450]	valid_0's rmsse: 0.774921
# [500]	valid_0's rmsse: 0.77479
# Did not meet early stopping. Best iteration is:
# [493]	valid_0's rmsse: 0.774786
# Elapsed time for training the model: 1.850570301214854 min.
# ---------------------------------------------------------------------------
# Training model for site: MLB
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 9024166, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.851704
# [100]	valid_0's rmsse: 0.839191
# [150]	valid_0's rmsse: 0.834946
# [200]	valid_0's rmsse: 0.83289
# [250]	valid_0's rmsse: 0.831633
# [300]	valid_0's rmsse: 0.831091
# [350]	valid_0's rmsse: 0.830611
# [400]	valid_0's rmsse: 0.830321
# [450]	valid_0's rmsse: 0.8301
# [500]	valid_0's rmsse: 0.829951
# Did not meet early stopping. Best iteration is:
# [495]	valid_0's rmsse: 0.829925
# Elapsed time for training the model: 5.522226516405741 min.
# ---------------------------------------------------------------------------
# Training model for site: MLM
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 7103708, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.77549
# [100]	valid_0's rmsse: 0.764289
# [150]	valid_0's rmsse: 0.761066
# [200]	valid_0's rmsse: 0.759635
# [250]	valid_0's rmsse: 0.758936
# [300]	valid_0's rmsse: 0.758618
# [350]	valid_0's rmsse: 0.758359
# [400]	valid_0's rmsse: 0.758204
# [450]	valid_0's rmsse: 0.758107
# [500]	valid_0's rmsse: 0.758049
# Did not meet early stopping. Best iteration is:
# [493]	valid_0's rmsse: 0.758036
# Elapsed time for training the model: 4.496811691919962 min.
# MLA error: 0.7747860010226851
# MLB error: 0.8299253320772688
# MLM error: 0.7580363952597601
# ---------------------------------------------------------------------------
# Training model for site: MLA
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 1515336, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.787493
# [100]	valid_0's rmsse: 0.779148
# [150]	valid_0's rmsse: 0.77664
# [200]	valid_0's rmsse: 0.775413
# [250]	valid_0's rmsse: 0.774702
# [300]	valid_0's rmsse: 0.774397
# [350]	valid_0's rmsse: 0.774162
# [400]	valid_0's rmsse: 0.774034
# [450]	valid_0's rmsse: 0.773951
# [500]	valid_0's rmsse: 0.773875
# Did not meet early stopping. Best iteration is:
# [493]	valid_0's rmsse: 0.773872
# Elapsed time for training the model: 1.9683496514956156 min.
# ---------------------------------------------------------------------------
# Training model for site: MLB
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 9024166, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.845973
# [100]	valid_0's rmsse: 0.835125
# [150]	valid_0's rmsse: 0.831769
# [200]	valid_0's rmsse: 0.830179
# [250]	valid_0's rmsse: 0.829251
# [300]	valid_0's rmsse: 0.828888
# [350]	valid_0's rmsse: 0.82858
# [400]	valid_0's rmsse: 0.828392
# [450]	valid_0's rmsse: 0.828294
# [500]	valid_0's rmsse: 0.828203
# Did not meet early stopping. Best iteration is:
# [493]	valid_0's rmsse: 0.828191
# Elapsed time for training the model: 5.366124244530996 min.
# ---------------------------------------------------------------------------
# Training model for site: MLM
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 7103708, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.77081
# [100]	valid_0's rmsse: 0.761656
# [150]	valid_0's rmsse: 0.759242
# [200]	valid_0's rmsse: 0.758239
# [250]	valid_0's rmsse: 0.757764
# [300]	valid_0's rmsse: 0.757544
# [350]	valid_0's rmsse: 0.757407
# [400]	valid_0's rmsse: 0.757343
# [450]	valid_0's rmsse: 0.757289
# [500]	valid_0's rmsse: 0.757268
# Did not meet early stopping. Best iteration is:
# [493]	valid_0's rmsse: 0.757241
# Elapsed time for training the model: 4.598544438680013 min.
# MLA error: 0.7738716156041439
# MLB error: 0.8281908492694372
# MLM error: 0.7572407297196494
# ---------------------------------------------------------------------------
# Training model for site: MLA
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 1515336, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.784818
# [100]	valid_0's rmsse: 0.777653
# [150]	valid_0's rmsse: 0.775627
# [200]	valid_0's rmsse: 0.774704
# [250]	valid_0's rmsse: 0.774203
# [300]	valid_0's rmsse: 0.77402
# [350]	valid_0's rmsse: 0.773859
# [400]	valid_0's rmsse: 0.773778
# [450]	valid_0's rmsse: 0.77376
# [500]	valid_0's rmsse: 0.773763
# Did not meet early stopping. Best iteration is:
# [493]	valid_0's rmsse: 0.773727
# Elapsed time for training the model: 1.8009283145268757 min.
# ---------------------------------------------------------------------------
# Training model for site: MLB
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 9024166, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.842458
# [100]	valid_0's rmsse: 0.83321
# [150]	valid_0's rmsse: 0.830392
# [200]	valid_0's rmsse: 0.829151
# [250]	valid_0's rmsse: 0.828423
# [300]	valid_0's rmsse: 0.828153
# [350]	valid_0's rmsse: 0.827922
# [400]	valid_0's rmsse: 0.827796
# [450]	valid_0's rmsse: 0.8277
# [500]	valid_0's rmsse: 0.827675
# Did not meet early stopping. Best iteration is:
# [493]	valid_0's rmsse: 0.827653
# Elapsed time for training the model: 5.374796803792318 min.
# ---------------------------------------------------------------------------
# Training model for site: MLM
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 7103708, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.768004
# [100]	valid_0's rmsse: 0.760491
# [150]	valid_0's rmsse: 0.758619
# [200]	valid_0's rmsse: 0.757904
# [250]	valid_0's rmsse: 0.757546
# [300]	valid_0's rmsse: 0.757467
# [350]	valid_0's rmsse: 0.757372
# Early stopping, best iteration is:
# [320]	valid_0's rmsse: 0.757361
# Elapsed time for training the model: 3.2212919076283772 min.
# MLA error: 0.7737265814005183
# MLB error: 0.8276526397939385
# MLM error: 0.7573607006389713
# ---------------------------------------------------------------------------
# Training model for site: MLA
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 1515336, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.782916
# [100]	valid_0's rmsse: 0.776759
# [150]	valid_0's rmsse: 0.775153
# [200]	valid_0's rmsse: 0.774421
# [250]	valid_0's rmsse: 0.77406
# Early stopping, best iteration is:
# [242]	valid_0's rmsse: 0.774022
# Elapsed time for training the model: 1.0466660698254904 min.
# ---------------------------------------------------------------------------
# Training model for site: MLB
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 9024166, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.839876
# [100]	valid_0's rmsse: 0.831939
# [150]	valid_0's rmsse: 0.829677
# [200]	valid_0's rmsse: 0.828668
# [250]	valid_0's rmsse: 0.828085
# [300]	valid_0's rmsse: 0.827934
# [350]	valid_0's rmsse: 0.827756
# [400]	valid_0's rmsse: 0.827682
# [450]	valid_0's rmsse: 0.827634
# [500]	valid_0's rmsse: 0.82763
# Did not meet early stopping. Best iteration is:
# [493]	valid_0's rmsse: 0.827604
# Elapsed time for training the model: 5.586305109659831 min.
# ---------------------------------------------------------------------------
# Training model for site: MLM
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 7103708, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.766308
# [100]	valid_0's rmsse: 0.760206
# [150]	valid_0's rmsse: 0.758759
# [200]	valid_0's rmsse: 0.758257
# [250]	valid_0's rmsse: 0.757969
# [300]	valid_0's rmsse: 0.757877
# Early stopping, best iteration is:
# [316]	valid_0's rmsse: 0.757809
# Elapsed time for training the model: 3.260894552866618 min.
# MLA error: 0.7740223716523784
# MLB error: 0.8276038449508571
# MLM error: 0.7578085654300991
# ---------------------------------------------------------------------------
# Training model for site: MLA
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 1515336, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.781577
# [100]	valid_0's rmsse: 0.776309
# [150]	valid_0's rmsse: 0.775
# [200]	valid_0's rmsse: 0.774366
# [250]	valid_0's rmsse: 0.77414
# Early stopping, best iteration is:
# [242]	valid_0's rmsse: 0.774106
# Elapsed time for training the model: 0.9868209759394327 min.
# ---------------------------------------------------------------------------
# Training model for site: MLB
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 9024166, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.837961
# [100]	valid_0's rmsse: 0.831087
# [150]	valid_0's rmsse: 0.82919
# [200]	valid_0's rmsse: 0.828364
# [250]	valid_0's rmsse: 0.827889
# [300]	valid_0's rmsse: 0.827762
# [350]	valid_0's rmsse: 0.827611
# [400]	valid_0's rmsse: 0.827579
# [450]	valid_0's rmsse: 0.827548
# [500]	valid_0's rmsse: 0.827538
# Did not meet early stopping. Best iteration is:
# [493]	valid_0's rmsse: 0.827517
# Elapsed time for training the model: 5.398677361011505 min.
# ---------------------------------------------------------------------------
# Training model for site: MLM
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 7103708, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.765154
# [100]	valid_0's rmsse: 0.760172
# [150]	valid_0's rmsse: 0.759084
# [200]	valid_0's rmsse: 0.758678
# [250]	valid_0's rmsse: 0.758489
# Early stopping, best iteration is:
# [242]	valid_0's rmsse: 0.75846
# Elapsed time for training the model: 2.550351850191752 min.
# MLA error: 0.7741060546720313
# MLB error: 0.8275174600611445
# MLM error: 0.7584603124594959
# ---------------------------------------------------------------------------
# Training model for site: MLA
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 1515336, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.780655
# [100]	valid_0's rmsse: 0.776041
# [150]	valid_0's rmsse: 0.774912
# [200]	valid_0's rmsse: 0.774415
# [250]	valid_0's rmsse: 0.774206
# Early stopping, best iteration is:
# [242]	valid_0's rmsse: 0.774182
# Elapsed time for training the model: 1.004334032535553 min.
# ---------------------------------------------------------------------------
# Training model for site: MLB
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 9024166, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.8365
# [100]	valid_0's rmsse: 0.830447
# [150]	valid_0's rmsse: 0.828879
# [200]	valid_0's rmsse: 0.828226
# [250]	valid_0's rmsse: 0.827836
# [300]	valid_0's rmsse: 0.827744
# [350]	valid_0's rmsse: 0.827613
# [400]	valid_0's rmsse: 0.827583
# Early stopping, best iteration is:
# [380]	valid_0's rmsse: 0.827577
# Elapsed time for training the model: 4.555471614996592 min.
# ---------------------------------------------------------------------------
# Training model for site: MLM
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 7103708, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.764185
# [100]	valid_0's rmsse: 0.760079
# [150]	valid_0's rmsse: 0.759183
# [200]	valid_0's rmsse: 0.758874
# [250]	valid_0's rmsse: 0.758742
# Early stopping, best iteration is:
# [240]	valid_0's rmsse: 0.758727
# Elapsed time for training the model: 2.436153745651245 min.
# MLA error: 0.7741815659227458
# MLB error: 0.8275771869302759
# MLM error: 0.7587271176312494
# ---------------------------------------------------------------------------
# Training model for site: MLA
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 1515336, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.779952
# [100]	valid_0's rmsse: 0.775805
# [150]	valid_0's rmsse: 0.7748
# [200]	valid_0's rmsse: 0.774508
# [250]	valid_0's rmsse: 0.774336
# Early stopping, best iteration is:
# [242]	valid_0's rmsse: 0.774295
# Elapsed time for training the model: 1.0194945891698202 min.
# ---------------------------------------------------------------------------
# Training model for site: MLB
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 9024166, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.835407
# [100]	valid_0's rmsse: 0.829937
# [150]	valid_0's rmsse: 0.828633
# [200]	valid_0's rmsse: 0.828139
# [250]	valid_0's rmsse: 0.827824
# [300]	valid_0's rmsse: 0.827775
# [350]	valid_0's rmsse: 0.827705
# Early stopping, best iteration is:
# [324]	valid_0's rmsse: 0.8277
# Elapsed time for training the model: 3.9048773964246113 min.
# ---------------------------------------------------------------------------
# Training model for site: MLM
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 7103708, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.763571
# [100]	valid_0's rmsse: 0.760179
# [150]	valid_0's rmsse: 0.759487
# [200]	valid_0's rmsse: 0.759241
# [250]	valid_0's rmsse: 0.759158
# Early stopping, best iteration is:
# [240]	valid_0's rmsse: 0.759127
# Elapsed time for training the model: 2.4866476535797117 min.
# MLA error: 0.774295027497772
# MLB error: 0.8276996381556744
# MLM error: 0.7591270389267161

# %%
pd.DataFrame(results).sort_values("rmsse_AVG", ascending=True)
# Out:
#    alpha  rmsse_MLA  rmsse_MLB  rmsse_MLM  rmsse_AVG
# 5    1.2   0.773727   0.827653   0.757361   0.786247
# 4    1.0   0.773872   0.828191   0.757241   0.786434
# 6    1.4   0.774022   0.827604   0.757809   0.786478
# 7    1.6   0.774106   0.827517   0.758460   0.786695
# 8    1.8   0.774182   0.827577   0.758727   0.786829
# 9    2.0   0.774295   0.827700   0.759127   0.787041
# 3    0.8   0.774786   0.829925   0.758036   0.787583
# 2    0.6   0.778498   0.833971   0.760988   0.791153
# 1    0.4   0.785907   0.842851   0.767860   0.798873
# 0    0.2   0.801752   0.861092   0.783388   0.815411

# %% [markdown]
# ***
# ## Model assessment: tweedie loss

# %%
results = list()

for power in np.arange(1.0, 1.9, 0.1):

    _model_params = dict(model_params)
    _model_params["objective"] = "tweedie"
    _model_params["tweedie_variance_power"] = power

    models_by_site = list()

    for idx,site in enumerate(["MLA","MLB","MLM"]):
        
        print("-"*75)
        print(f"Training model for site: {site}")
        model = deepcopy(base_models[idx])
        model.set_params(_model_params)

        train_data = dataset.query("site_id == @site & sku in @skus_both").reset_index(drop=True)
        valid_idx = train_data.query("ds > '2021-03-01'").index

        tic = time.time()
        evaluator = RMSSE(train_data.loc[valid_idx, ["sku","y"]], scales)
        model.fit(fit_kwargs={"verbose_eval":50, "feval":evaluator.evaluate})
        models_by_site.append(model)
        tac = time.time()
        print(f"Elapsed time for training the model: {(tac-tic)/60} min.")

    errors = list()
    sites = ["MLA","MLB","MLM"]
    for site,model in zip(sites,models_by_site):
        error = model.model.model.best_score["valid_0"]["rmsse"]
        errors.append(error)
        print(site, f"error: {error}")

    results.append({
        "power":power, 
        "rmsse_MLA":errors[0], 
        "rmsse_MLB":errors[1],
        "rmsse_MLM":errors[2],
        "rmsse_AVG":np.mean(errors),
    })

    del models_by_site
    gc.collect()
# Out:
# ---------------------------------------------------------------------------
# Training model for site: MLA
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 1515336, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.784647
# [100]	valid_0's rmsse: 0.7824
# Early stopping, best iteration is:
# [75]	valid_0's rmsse: 0.781962
# Elapsed time for training the model: 0.40308866103490193 min.
# ---------------------------------------------------------------------------
# Training model for site: MLB
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 9024166, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.848195
# [100]	valid_0's rmsse: 0.83674
# [150]	valid_0's rmsse: 0.835146
# [200]	valid_0's rmsse: 0.834788
# [250]	valid_0's rmsse: 0.83472
# [300]	valid_0's rmsse: 0.834705
# Early stopping, best iteration is:
# [280]	valid_0's rmsse: 0.834688
# Elapsed time for training the model: 3.704009560743968 min.
# ---------------------------------------------------------------------------
# Training model for site: MLM
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 7103708, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 1.06021
# [100]	valid_0's rmsse: 0.801643
# [150]	valid_0's rmsse: 0.780694
# [200]	valid_0's rmsse: 0.778986
# [250]	valid_0's rmsse: 0.778929
# Early stopping, best iteration is:
# [255]	valid_0's rmsse: 0.778918
# Elapsed time for training the model: 2.885084108511607 min.
# MLA error: 0.7819621396664204
# MLB error: 0.8346880463717121
# MLM error: 0.7789183623514871
# ---------------------------------------------------------------------------
# Training model for site: MLA
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 1515336, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.782411
# Early stopping, best iteration is:
# [61]	valid_0's rmsse: 0.781211
# Elapsed time for training the model: 0.36000529925028485 min.
# ---------------------------------------------------------------------------
# Training model for site: MLB
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 9024166, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.834594
# Early stopping, best iteration is:
# [61]	valid_0's rmsse: 0.833423
# Elapsed time for training the model: 1.2494904041290282 min.
# ---------------------------------------------------------------------------
# Training model for site: MLM
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 7103708, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.777873
# Early stopping, best iteration is:
# [69]	valid_0's rmsse: 0.776249
# Elapsed time for training the model: 1.0459974129994711 min.
# MLA error: 0.7812110007872028
# MLB error: 0.8334234650167793
# MLM error: 0.7762492837394104
# ---------------------------------------------------------------------------
# Training model for site: MLA
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 1515336, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.781035
# Early stopping, best iteration is:
# [56]	valid_0's rmsse: 0.780562
# Elapsed time for training the model: 0.3553225000699361 min.
# ---------------------------------------------------------------------------
# Training model for site: MLB
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 9024166, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.833198
# Early stopping, best iteration is:
# [56]	valid_0's rmsse: 0.8327
# Elapsed time for training the model: 1.145260226726532 min.
# ---------------------------------------------------------------------------
# Training model for site: MLM
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 7103708, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.774612
# Early stopping, best iteration is:
# [56]	valid_0's rmsse: 0.774321
# Elapsed time for training the model: 0.9375665386517843 min.
# MLA error: 0.7805617502709135
# MLB error: 0.8326999343450195
# MLM error: 0.7743214581660908
# ---------------------------------------------------------------------------
# Training model for site: MLA
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 1515336, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.779972
# Early stopping, best iteration is:
# [56]	valid_0's rmsse: 0.779806
# Elapsed time for training the model: 0.3616103450457255 min.
# ---------------------------------------------------------------------------
# Training model for site: MLB
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 9024166, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.83229
# Early stopping, best iteration is:
# [56]	valid_0's rmsse: 0.83218
# Elapsed time for training the model: 1.1893602768580118 min.
# ---------------------------------------------------------------------------
# Training model for site: MLM
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 7103708, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.771482
# Early stopping, best iteration is:
# [43]	valid_0's rmsse: 0.770832
# Elapsed time for training the model: 0.8060683647791544 min.
# MLA error: 0.7798055190928463
# MLB error: 0.8321798471679829
# MLM error: 0.7708317176723262
# ---------------------------------------------------------------------------
# Training model for site: MLA
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 1515336, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.779205
# Early stopping, best iteration is:
# [43]	valid_0's rmsse: 0.779144
# Elapsed time for training the model: 0.3143464684486389 min.
# ---------------------------------------------------------------------------
# Training model for site: MLB
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 9024166, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.831793
# Early stopping, best iteration is:
# [43]	valid_0's rmsse: 0.831644
# Elapsed time for training the model: 1.0503874858220419 min.
# ---------------------------------------------------------------------------
# Training model for site: MLM
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 7103708, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.768853
# Early stopping, best iteration is:
# [43]	valid_0's rmsse: 0.767906
# Elapsed time for training the model: 0.820675790309906 min.
# MLA error: 0.7791442373077385
# MLB error: 0.8316437822077962
# MLM error: 0.7679060938439769
# ---------------------------------------------------------------------------
# Training model for site: MLA
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 1515336, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.778879
# Early stopping, best iteration is:
# [45]	valid_0's rmsse: 0.778819
# Elapsed time for training the model: 0.3041082978248596 min.
# ---------------------------------------------------------------------------
# Training model for site: MLB
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 9024166, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.831648
# Early stopping, best iteration is:
# [49]	valid_0's rmsse: 0.831644
# Elapsed time for training the model: 1.125265642007192 min.
# ---------------------------------------------------------------------------
# Training model for site: MLM
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 7103708, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.767012
# Early stopping, best iteration is:
# [42]	valid_0's rmsse: 0.766254
# Elapsed time for training the model: 0.7980608940124512 min.
# MLA error: 0.7788191541574312
# MLB error: 0.831644097020646
# MLM error: 0.7662540869042066
# ---------------------------------------------------------------------------
# Training model for site: MLA
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 1515336, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.778692
# Early stopping, best iteration is:
# [49]	valid_0's rmsse: 0.778674
# Elapsed time for training the model: 0.3279288649559021 min.
# ---------------------------------------------------------------------------
# Training model for site: MLB
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 9024166, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.831771
# Early stopping, best iteration is:
# [56]	valid_0's rmsse: 0.831727
# Elapsed time for training the model: 1.209948980808258 min.
# ---------------------------------------------------------------------------
# Training model for site: MLM
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 7103708, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.765959
# Early stopping, best iteration is:
# [45]	valid_0's rmsse: 0.765566
# Elapsed time for training the model: 0.835005251566569 min.
# MLA error: 0.7786743834284602
# MLB error: 0.8317270272767204
# MLM error: 0.7655662126569408
# ---------------------------------------------------------------------------
# Training model for site: MLA
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 1515336, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.778777
# Early stopping, best iteration is:
# [53]	valid_0's rmsse: 0.778715
# Elapsed time for training the model: 0.3283723950386047 min.
# ---------------------------------------------------------------------------
# Training model for site: MLB
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 9024166, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.832157
# Early stopping, best iteration is:
# [59]	valid_0's rmsse: 0.831915
# Elapsed time for training the model: 1.258558205763499 min.
# ---------------------------------------------------------------------------
# Training model for site: MLM
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 7103708, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.765616
# Early stopping, best iteration is:
# [46]	valid_0's rmsse: 0.765418
# Elapsed time for training the model: 0.8555524508158366 min.
# MLA error: 0.7787147462851811
# MLB error: 0.8319150406829938
# MLM error: 0.7654183975336948
# ---------------------------------------------------------------------------
# Training model for site: MLA
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 1515336, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.778898
# Early stopping, best iteration is:
# [60]	valid_0's rmsse: 0.778741
# Elapsed time for training the model: 0.3614389061927795 min.
# ---------------------------------------------------------------------------
# Training model for site: MLB
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 9024166, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.832716
# Early stopping, best iteration is:
# [65]	valid_0's rmsse: 0.832147
# Elapsed time for training the model: 1.2933810154596965 min.
# ---------------------------------------------------------------------------
# Training model for site: MLM
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 7103708, number of used features: 14
# Training until validation scores don't improve for 30 rounds
# [50]	valid_0's rmsse: 0.765827
# Early stopping, best iteration is:
# [48]	valid_0's rmsse: 0.765804
# Elapsed time for training the model: 0.8536561608314515 min.
# MLA error: 0.7787409807181819
# MLB error: 0.8321473096566896
# MLM error: 0.7658036674870905

# %%
pd.DataFrame(results).sort_values("rmsse_AVG", ascending=True)
# Out:
#    power  rmsse_MLA  rmsse_MLB  rmsse_MLM  rmsse_AVG
# 6    1.6   0.778674   0.831727   0.765566   0.791989
# 7    1.7   0.778715   0.831915   0.765418   0.792016
# 8    1.8   0.778741   0.832147   0.765804   0.792231
# 5    1.5   0.778819   0.831644   0.766254   0.792239
# 4    1.4   0.779144   0.831644   0.767906   0.792898
# 3    1.3   0.779806   0.832180   0.770832   0.794272
# 2    1.2   0.780562   0.832700   0.774321   0.795861
# 1    1.1   0.781211   0.833423   0.776249   0.796961
# 0    1.0   0.781962   0.834688   0.778918   0.798523

# %% [markdown]
# ***
